# %%
import pandas as pd

# %%
a = pd.read_csv("BIKE DETAILS.csv")
a
a['type'] = pd.Series(["Two Wheeler" for x in range(len(a.index))])
a['fuel'] = pd.Series(["Petrol" for x in range(len(a.index))])
a['transmission'] = pd.Series(["NaN" for x in range(len(a.index))])

a
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
# ...

# %%
list(a.columns.values)
# Out:
# ['name',
#  'selling_price',
#  'year',
#  'seller_type',
#  'owner',
#  'km_driven',
#  'ex_showroom_price',
#  'type',
#  'fuel',
#  'transmission']

# %%
b =pd.read_csv("CAR DETAILS FROM CAR DEKHO.csv")
b
b['type'] = pd.Series(["Four Wheeler" for x in range(len(b.index))])
b['ex_showroom_price'] = pd.Series(["NaN" for x in range(len(b.index))])
b
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner          type  \
# ...

# %%
b = b[['name','selling_price','year','seller_type','owner','km_driven','ex_showroom_price','type','fuel','transmission']]

# %%
b
# Out:
#                                      name  selling_price  year seller_type  \
# 0                           Maruti 800 AC          60000  2007  Individual
# 1                Maruti Wagon R LXI Minor         135000  2007  Individual
# 2                    Hyundai Verna 1.6 SX         600000  2012  Individual
# 3                  Datsun RediGO T Option         250000  2017  Individual
# 4                   Honda Amaze VX i-DTEC         450000  2014  Individual
# ...                                   ...            ...   ...         ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)         409999  2014  Individual
# 4336           Hyundai i20 Magna 1.4 CRDi         409999  2014  Individual
# 4337                  Maruti 800 AC BSIII         110000  2009  Individual
# 4338     Hyundai Creta 1.6 CRDi SX Option         865000  2016  Individual
# 4339                     Renault KWID RXT         225000  2016  Individual
#
# ...

# %%
a
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
# ...

# %%
merged = pd.concat([a,b])
merged
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)         409999  2014  Individual
# 4336           Hyundai i20 Magna 1.4 CRDi         409999  2014  Individual
# 4337                  Maruti 800 AC BSIII         110000  2009  Individual
# 4338     Hyundai Creta 1.6 CRDi SX Option         865000  2016  Individual
# 4339                     Renault KWID RXT         225000  2016  Individual
#
# ...

# %%
merged.to_csv('vehical.csv')
